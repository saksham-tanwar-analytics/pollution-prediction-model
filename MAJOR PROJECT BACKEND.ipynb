# %%
# IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#IMPORTING DATASET
df=pd.read_csv("air_pollution_data.csv")
df
# Out:
#                 city        date        aqi       co     no    no2      o3  \
# 0          Ahmedabad  30-11-2020  Very Poor   520.71   2.38  16.28  130.18
# 1          Ahmedabad  01-12-2020  Very Poor  1682.28   7.71  54.84    0.73
# 2          Ahmedabad  02-12-2020  Very Poor  1815.80  16.54  49.35    0.17
# 3          Ahmedabad  03-12-2020  Very Poor  2296.45  41.57  40.10    0.00
# 4          Ahmedabad  04-12-2020  Very Poor  2189.64  23.92  58.95    0.02
# ...              ...         ...        ...      ...    ...    ...     ...
# 23499  Visakhapatnam  21-05-2023   Moderate   353.81   0.00   2.08  100.14
# 23500  Visakhapatnam  22-05-2023   Moderate   380.52   0.00   3.77   82.97
# 23501  Visakhapatnam  23-05-2023   Moderate   390.53   0.00   4.28   80.11
# 23502  Visakhapatnam  24-05-2023   Moderate   300.41   0.00   1.36   95.84
# 23503  Visakhapatnam  25-05-2023       Poor   427.25   0.00   6.00   88.69
#
#          so2   pm2_5    pm10    nh3
# 0      47.68   65.96   72.13   8.36
# 1      21.70  120.95  154.53  27.36
# 2      23.84  133.47  172.63  28.12
# 3      35.76  150.37  202.15  36.48
# 4      28.13  160.79  205.80  40.53
# ...      ...     ...     ...    ...
# 23499   4.11   37.53   47.09   0.08
# 23500   5.07   32.17   43.44   1.74
# 23501   5.19   36.01   48.06   1.20
# 23502   2.21   30.17   48.89   0.00
# 23503  10.73   52.36   61.41   0.20
#
# [23504 rows x 11 columns]

# %%
# EXPLORATORY DATA ANALYSIS

# %%
# to see the shape
df.shape
# Out:
# (23504, 13)

# %%
# to see statistical description
df.describe()
# Out:
#                  co           no           no2            o3           so2  \
# count  23504.000000  23504.00000  23504.000000  23504.000000  23504.000000
# mean    1113.224543      6.00554     25.044104     35.059777     15.971449
# std     1401.770372     24.50272     25.839242     31.901760     23.943464
# min      173.570000      0.00000      0.310000      0.000000      0.190000
# 25%      447.270000      0.00000      8.740000      7.870000      4.470000
# 50%      700.950000      0.00000     16.450000     28.250000      7.990000
# 75%     1188.280000      0.27000     32.220000     54.360000     16.450000
# max    23071.290000    457.76000    331.760000    406.270000    442.510000
#
#               pm2_5          pm10           nh3           day         month  \
# count  23504.000000  23504.000000  23504.000000  23504.000000  23504.000000
# mean      98.598310    121.848091     12.060212     15.474558      6.301991
# std      135.572391    160.429589     17.544759      8.960984      3.541323
# min        0.500000      0.580000      0.000000      1.000000      1.000000
# 25%       24.677500     32.277500      2.340000      7.000000      3.000000
# 50%       58.860000     75.775000      6.520000     16.000000      6.000000
# 75%      117.605000    147.642500     15.830000     23.000000      9.000000
# max     2203.550000   2429.130000    352.620000     31.000000     12.000000
#
#                year
# count  23504.000000
# mean    2021.684735
# std        0.777997
# min     2020.000000
# 25%     2021.000000
# 50%     2022.000000
# 75%     2022.000000
# max     2023.000000

# %%
# to see information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23504 entries, 0 to 23503
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    23504 non-null  object
#  1   aqi     23504 non-null  object
#  2   co      23504 non-null  float64
#  3   no      23504 non-null  float64
#  4   no2     23504 non-null  float64
#  5   o3      23504 non-null  float64
#  6   so2     23504 non-null  float64
#  7   pm2_5   23504 non-null  float64
#  8   pm10    23504 non-null  float64
#  9   nh3     23504 non-null  float64
#  10  day     23504 non-null  int64
#  11  month   23504 non-null  int64
#  12  year    23504 non-null  int64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 2.3+ MB

# %%
# to see columns/attributes
df.columns
# Out:
# Index(['city', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
# to see first 5 and last 5 rows
df.head()
# Out:
#         city        aqi       co     no    no2      o3    so2   pm2_5    pm10  \
# 0  Ahmedabad  Very Poor   520.71   2.38  16.28  130.18  47.68   65.96   72.13
# 1  Ahmedabad  Very Poor  1682.28   7.71  54.84    0.73  21.70  120.95  154.53
# 2  Ahmedabad  Very Poor  1815.80  16.54  49.35    0.17  23.84  133.47  172.63
# 3  Ahmedabad  Very Poor  2296.45  41.57  40.10    0.00  35.76  150.37  202.15
# 4  Ahmedabad  Very Poor  2189.64  23.92  58.95    0.02  28.13  160.79  205.80
#
#      nh3  day  month  year
# 0   8.36   30     11  2020
# 1  27.36   12      1  2020
# 2  28.12   12      2  2020
# 3  36.48   12      3  2020
# 4  40.53   12      4  2020

# %%
df.tail()
# Out:
#                 city       aqi      co   no   no2      o3    so2  pm2_5  \
# 23499  Visakhapatnam  Moderate  353.81  0.0  2.08  100.14   4.11  37.53
# 23500  Visakhapatnam  Moderate  380.52  0.0  3.77   82.97   5.07  32.17
# 23501  Visakhapatnam  Moderate  390.53  0.0  4.28   80.11   5.19  36.01
# 23502  Visakhapatnam  Moderate  300.41  0.0  1.36   95.84   2.21  30.17
# 23503  Visakhapatnam      Poor  427.25  0.0  6.00   88.69  10.73  52.36
#
#         pm10   nh3  day  month  year
# 23499  47.09  0.08   21      5  2023
# 23500  43.44  1.74   22      5  2023
# 23501  48.06  1.20   23      5  2023
# 23502  48.89  0.00   24      5  2023
# 23503  61.41  0.20   25      5  2023

# %%
# to see unique city in city columns
df['city'].unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
# here we have 26 cities

# %%
# Here we have 5 categories of AQI

# %%
# to see unique standard AQI
df['aqi'].unique()
# Out:
# array(['Very Poor', ' Poor', 'Fair', 'Good', 'Moderate'], dtype=object)

# %%
#To see count of values of standard AQI
df['aqi'].value_counts()              # maximum of standard 5 means severe cases
# Out:
# Very Poor    12458
#  Poor         4324
# Good          2618
# Fair          2372
# Moderate      1732
# Name: aqi, dtype: int64

# %%
sns.histplot(df['aqi'])
# Out:
# <AxesSubplot:xlabel='aqi', ylabel='Count'>

# %%
# to see total no.of unique values
df.nunique()
# Out:
# city        26
# aqi          5
# co         492
# no         670
# no2        601
# o3         636
# so2        646
# pm2_5    13663
# pm10     14840
# nh3        613
# day         31
# month       12
# year         4
# dtype: int64

# %%
# records where city  is Ahmedabad and aqi shows very Poor

# %%
df[(df['city']=="Ahmedabad") & (df['aqi']=="Very Poor")]
# Out:
#           city        aqi       co     no    no2      o3     so2   pm2_5  \
# 0    Ahmedabad  Very Poor   520.71   2.38  16.28  130.18   47.68   65.96
# 1    Ahmedabad  Very Poor  1682.28   7.71  54.84    0.73   21.70  120.95
# 2    Ahmedabad  Very Poor  1815.80  16.54  49.35    0.17   23.84  133.47
# 3    Ahmedabad  Very Poor  2296.45  41.57  40.10    0.00   35.76  150.37
# 4    Ahmedabad  Very Poor  2189.64  23.92  58.95    0.02   28.13  160.79
# ..         ...        ...      ...    ...    ...     ...     ...     ...
# 867  Ahmedabad  Very Poor  2750.40  54.09  36.33    0.00   68.66  132.41
# 872  Ahmedabad  Very Poor  1602.17   7.71  50.72    0.51   40.53   78.39
# 874  Ahmedabad  Very Poor  4005.43  44.70  82.25    0.00  103.00  238.97
# 882  Ahmedabad  Very Poor  1976.01   2.63  69.23    2.50   47.68  126.96
# 889  Ahmedabad  Very Poor  2243.04  34.87  53.47    0.00   53.88  102.27
#
#        pm10    nh3  day  month  year
# 0     72.13   8.36   30     11  2020
# 1    154.53  27.36   12      1  2020
# 2    172.63  28.12   12      2  2020
# 3    202.15  36.48   12      3  2020
# 4    205.80  40.53   12      4  2020
# ..      ...    ...  ...    ...   ...
# 867  186.54  51.17   19      4  2023
# 872  114.58  25.33   24      4  2023
# 874  286.67  61.81   26      4  2023
# 882  163.14  25.59    5      4  2023
# 889  162.56  29.89    5     11  2023
#
# [497 rows x 13 columns]

# %%
# records where city is delhi and aqi is Poor
df[(df['city']=="Delhi") & (df['aqi']=="Very Poor")]
# Out:
#        city        aqi       co     no    no2      o3     so2   pm2_5    pm10  \
# 9040  Delhi  Very Poor   988.01   1.24  13.71  205.99   34.33  133.73  156.15
# 9041  Delhi  Very Poor  3150.94  30.40  66.49    0.00   14.90  299.99  428.61
# 9042  Delhi  Very Poor  3524.78  18.11  71.97    0.05   12.16  455.67  571.47
# 9043  Delhi  Very Poor  1922.61   0.03  52.78   27.54   11.09  208.94  266.25
# 9044  Delhi  Very Poor  3738.40   0.64  78.14   11.00   16.69  595.27  748.71
# ...     ...        ...      ...    ...    ...     ...     ...     ...     ...
# 9933  Delhi  Very Poor  6355.29  67.06  95.96    0.00  103.95  395.87  579.79
# 9934  Delhi  Very Poor  3204.35  10.84  67.17    0.36   62.94  202.46  347.05
# 9939  Delhi  Very Poor  3070.83  12.85  81.57    0.08   69.62  172.37  327.52
# 9940  Delhi  Very Poor  1575.47   0.32  50.04    9.92   31.95   81.03  186.17
# 9943  Delhi  Very Poor  1161.58   0.00  24.33   62.94   28.85   82.46  108.60
#
#         nh3  day  month  year
# 9040   9.88   30     11  2020
# 9041  16.09   12      1  2020
# 9042  10.64   12      2  2020
# 9043  10.13   12      3  2020
# 9044  10.26   12      4  2020
# ...     ...  ...    ...   ...
# 9933  57.76   15      5  2023
# 9934  30.15   16      5  2023
# 9939  66.88   21      5  2023
# 9940  23.31   22      5  2023
# 9943   8.87   25      5  2023
#
# [779 rows x 13 columns]

# %%
fig = plt.figure(figsize =(15, 7))
plt.pie(df['no2'].head(5), labels = df['city'].head(5))

# show plot
plt.show()

# %%
# to see bar distribution of
sns.barplot(x='co', y='city', data=df)
# Out:
# <AxesSubplot:xlabel='co', ylabel='city'>

# %%
# to see bar distribution of
sns.barplot(x='no', y='city', data=df)
# Out:
# <AxesSubplot:xlabel='no', ylabel='city'>

# %%
# to see correlation in heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# to see scatter plot for relationship betwee co and no
sns.scatterplot(x="co",y='no',data=df)
# Out:
# <AxesSubplot:xlabel='co', ylabel='no'>

# %%
# to see scatter plot for relationship between no and o3
sns.scatterplot(x="no",y='o3',data=df)
# Out:
# <AxesSubplot:xlabel='no', ylabel='o3'>

# %%
 #to see scatter plot for relationship between no and o3
sns.scatterplot(x="pm2_5",y='pm10',data=df)
# Out:
# <AxesSubplot:xlabel='pm2_5', ylabel='pm10'>

# %%
# to see correlation
df.corr()
# Out:
#              co        no       no2        o3       so2     pm2_5      pm10  \
# co     1.000000  0.843799  0.805820 -0.313232  0.631510  0.929881  0.935345
# no     0.843799  1.000000  0.499226 -0.267879  0.532777  0.719160  0.718655
# no2    0.805820  0.499226  1.000000 -0.380578  0.708760  0.737977  0.755135
# o3    -0.313232 -0.267879 -0.380578  1.000000 -0.163729 -0.191523 -0.203824
# so2    0.631510  0.532777  0.708760 -0.163729  1.000000  0.552935  0.562396
# pm2_5  0.929881  0.719160  0.737977 -0.191523  0.552935  1.000000  0.990648
# pm10   0.935345  0.718655  0.755135 -0.203824  0.562396  0.990648  1.000000
# nh3    0.603286  0.416600  0.608555 -0.192751  0.468437  0.558785  0.586979
# day   -0.008076  0.001639 -0.006565 -0.027939 -0.007025 -0.008814 -0.009567
# month  0.012134  0.030423 -0.001430 -0.081670 -0.006754  0.009382  0.001504
# year  -0.003418 -0.017672  0.009093  0.047691  0.009188 -0.024737 -0.018249
#
#             nh3       day     month      year
# co     0.603286 -0.008076  0.012134 -0.003418
# no     0.416600  0.001639  0.030423 -0.017672
# no2    0.608555 -0.006565 -0.001430  0.009093
# o3    -0.192751 -0.027939 -0.081670  0.047691
# so2    0.468437 -0.007025 -0.006754  0.009188
# pm2_5  0.558785 -0.008814  0.009382 -0.024737
# pm10   0.586979 -0.009567  0.001504 -0.018249
# nh3    1.000000 -0.010987 -0.033074  0.042999
# day   -0.010987  1.000000 -0.026304 -0.088503
# month -0.033074 -0.026304  1.000000 -0.235665
# year   0.042999 -0.088503 -0.235665  1.000000

# %%
#let visulaize
sns.pairplot(df)
plt.show()

# %%
sns.histplot(bins=20,data=df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Now to apply encoding on few columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['city']=le.fit_transform(df['city'])
df['aqi']=le.fit_transform(df['aqi'])

# %%
print(df)
# Out:
#        city  aqi       co     no    no2      o3    so2   pm2_5    pm10    nh3  \
# 0         0    4   520.71   2.38  16.28  130.18  47.68   65.96   72.13   8.36
# 1         0    4  1682.28   7.71  54.84    0.73  21.70  120.95  154.53  27.36
# 2         0    4  1815.80  16.54  49.35    0.17  23.84  133.47  172.63  28.12
# 3         0    4  2296.45  41.57  40.10    0.00  35.76  150.37  202.15  36.48
# 4         0    4  2189.64  23.92  58.95    0.02  28.13  160.79  205.80  40.53
# ...     ...  ...      ...    ...    ...     ...    ...     ...     ...    ...
# 23499    25    3   353.81   0.00   2.08  100.14   4.11   37.53   47.09   0.08
# 23500    25    3   380.52   0.00   3.77   82.97   5.07   32.17   43.44   1.74
# 23501    25    3   390.53   0.00   4.28   80.11   5.19   36.01   48.06   1.20
# 23502    25    3   300.41   0.00   1.36   95.84   2.21   30.17   48.89   0.00
# 23503    25    0   427.25   0.00   6.00   88.69  10.73   52.36   61.41   0.20
#
#        day  month  year
# 0       30     11  2020
# 1       12      1  2020
# 2       12      2  2020
# 3       12      3  2020
# 4       12      4  2020
# ...    ...    ...   ...
# 23499   21      5  2023
# 23500   22      5  2023
# 23501   23      5  2023
# 23502   24      5  2023
# 23503   25      5  2023
#
# [23504 rows x 13 columns]

# %%
# HERE 4 denotes Very Poor, 3 denotes Poor, 2 denotes Moderate, 1 denotes Fair, 0 denotes Good

# %%
# Now To extract independent and dependent variables
X = df.iloc[:,[0, 2,4,5,6,7,8,9,12]].values
Y = df.iloc[:, 1].values

# %%
print(X)
# Out:
# [[0.00000e+00 5.20710e+02 1.62800e+01 ... 7.21300e+01 8.36000e+00
#   2.02000e+03]
#  [0.00000e+00 1.68228e+03 5.48400e+01 ... 1.54530e+02 2.73600e+01
#   2.02000e+03]
#  [0.00000e+00 1.81580e+03 4.93500e+01 ... 1.72630e+02 2.81200e+01
#   2.02000e+03]
#  ...
#  [2.50000e+01 3.90530e+02 4.28000e+00 ... 4.80600e+01 1.20000e+00
#   2.02300e+03]
#  [2.50000e+01 3.00410e+02 1.36000e+00 ... 4.88900e+01 0.00000e+00
#   2.02300e+03]
#  [2.50000e+01 4.27250e+02 6.00000e+00 ... 6.14100e+01 2.00000e-01
#   2.02300e+03]]

# %%
Y
# Out:
# array([4, 4, 4, ..., 3, 3, 0])

# %%
#Now Split the data in training and testing
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=5)

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# st_x = StandardScaler()
# X_train = st_x.fit_transform(X_train)
# X_test = st_x.transform(X_test)

# %%
df
# Out:
#        city  aqi       co     no    no2      o3    so2   pm2_5    pm10    nh3  \
# 0         0    4   520.71   2.38  16.28  130.18  47.68   65.96   72.13   8.36
# 1         0    4  1682.28   7.71  54.84    0.73  21.70  120.95  154.53  27.36
# 2         0    4  1815.80  16.54  49.35    0.17  23.84  133.47  172.63  28.12
# 3         0    4  2296.45  41.57  40.10    0.00  35.76  150.37  202.15  36.48
# 4         0    4  2189.64  23.92  58.95    0.02  28.13  160.79  205.80  40.53
# ...     ...  ...      ...    ...    ...     ...    ...     ...     ...    ...
# 23499    25    3   353.81   0.00   2.08  100.14   4.11   37.53   47.09   0.08
# 23500    25    3   380.52   0.00   3.77   82.97   5.07   32.17   43.44   1.74
# 23501    25    3   390.53   0.00   4.28   80.11   5.19   36.01   48.06   1.20
# 23502    25    3   300.41   0.00   1.36   95.84   2.21   30.17   48.89   0.00
# 23503    25    0   427.25   0.00   6.00   88.69  10.73   52.36   61.41   0.20
#
#        day  month  year
# 0       30     11  2020
# 1       12      1  2020
# 2       12      2  2020
# 3       12      3  2020
# 4       12      4  2020
# ...    ...    ...   ...
# 23499   21      5  2023
# 23500   22      5  2023
# 23501   23      5  2023
# 23502   24      5  2023
# 23503   25      5  2023
#
# [23504 rows x 13 columns]

# %%
X
# Out:
# array([[0.00000e+00, 5.20710e+02, 1.62800e+01, ..., 7.21300e+01,
#         8.36000e+00, 2.02000e+03],
#        [0.00000e+00, 1.68228e+03, 5.48400e+01, ..., 1.54530e+02,
#         2.73600e+01, 2.02000e+03],
#        [0.00000e+00, 1.81580e+03, 4.93500e+01, ..., 1.72630e+02,
#         2.81200e+01, 2.02000e+03],
#        ...,
#        [2.50000e+01, 3.90530e+02, 4.28000e+00, ..., 4.80600e+01,
#         1.20000e+00, 2.02300e+03],
#        [2.50000e+01, 3.00410e+02, 1.36000e+00, ..., 4.88900e+01,
#         0.00000e+00, 2.02300e+03],
#        [2.50000e+01, 4.27250e+02, 6.00000e+00, ..., 6.14100e+01,
#         2.00000e-01, 2.02300e+03]])

# %%
Y_test
# Out:
# array([4, 1, 4, ..., 1, 0, 2])

# %%
X_train
# Out:
# array([[2.40000e+01, 7.00950e+02, 1.54200e+01, ..., 4.07400e+01,
#         2.31000e+00, 2.02300e+03],
#        [1.70000e+01, 4.67300e+02, 8.31000e+00, ..., 7.64400e+01,
#         9.40000e-01, 2.02300e+03],
#        [3.00000e+00, 1.94931e+03, 6.58000e+01, ..., 1.66480e+02,
#         9.22100e+01, 2.02200e+03],
#        ...,
#        [2.20000e+01, 2.93730e+02, 5.48000e+00, ..., 5.75000e+00,
#         3.80000e-01, 2.02200e+03],
#        [2.00000e+01, 2.63690e+02, 7.54000e+00, ..., 5.02000e+00,
#         1.04000e+00, 2.02200e+03],
#        [3.00000e+00, 6.40870e+02, 7.11000e+00, ..., 7.24100e+01,
#         2.35600e+01, 2.02100e+03]])

# %% [markdown]
# # APPLY LOGISTIC REGRESSION

# %%
# Now to apply models
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# C:\Users\Akshay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_pred=lr.predict(X_test)
lr_pred
# Out:
# array([4, 2, 4, ..., 1, 0, 1])

# %%
# to check classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.75      0.70      1084
#            1       0.63      0.64      0.63       544
#            2       0.79      0.87      0.83       640
#            3       0.42      0.20      0.28       454
#            4       0.94      0.95      0.95      3154
#
#     accuracy                           0.82      5876
#    macro avg       0.69      0.68      0.68      5876
# weighted avg       0.81      0.82      0.81      5876

# %%
X
# Out:
# array([[0.00000e+00, 5.20710e+02, 1.62800e+01, ..., 7.21300e+01,
#         8.36000e+00, 2.02000e+03],
#        [0.00000e+00, 1.68228e+03, 5.48400e+01, ..., 1.54530e+02,
#         2.73600e+01, 2.02000e+03],
#        [0.00000e+00, 1.81580e+03, 4.93500e+01, ..., 1.72630e+02,
#         2.81200e+01, 2.02000e+03],
#        ...,
#        [2.50000e+01, 3.90530e+02, 4.28000e+00, ..., 4.80600e+01,
#         1.20000e+00, 2.02300e+03],
#        [2.50000e+01, 3.00410e+02, 1.36000e+00, ..., 4.88900e+01,
#         0.00000e+00, 2.02300e+03],
#        [2.50000e+01, 4.27250e+02, 6.00000e+00, ..., 6.14100e+01,
#         2.00000e-01, 2.02300e+03]])

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred=dt.predict(X_test)
dt_pred
# Out:
# array([4, 1, 4, ..., 1, 0, 2])

# %%
# to check classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1084
#            1       0.99      1.00      0.99       544
#            2       1.00      1.00      1.00       640
#            3       0.97      0.97      0.97       454
#            4       1.00      1.00      1.00      3154
#
#     accuracy                           0.99      5876
#    macro avg       0.99      0.99      0.99      5876
# weighted avg       0.99      0.99      0.99      5876

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred=rf.predict(X_test)
rf_pred
# Out:
# array([4, 1, 4, ..., 1, 0, 2])

# %%
# to check classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1084
#            1       1.00      0.99      0.99       544
#            2       1.00      1.00      1.00       640
#            3       0.98      0.98      0.98       454
#            4       1.00      1.00      1.00      3154
#
#     accuracy                           0.99      5876
#    macro avg       0.99      0.99      0.99      5876
# weighted avg       0.99      0.99      0.99      5876

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svm=SVC(kernel="rbf")
svm.fit(X_train,Y_train)
# Out:
# SVC()

# %%
svm_pred=svm.predict(X_test)
svm_pred
# Out:
# array([4, 2, 4, ..., 2, 0, 1])

# %%
# to check classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test,svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.74      0.64      1084
#            1       0.53      0.46      0.49       544
#            2       0.68      0.88      0.77       640
#            3       0.00      0.00      0.00       454
#            4       0.94      0.94      0.94      3154
#
#     accuracy                           0.78      5876
#    macro avg       0.54      0.60      0.57      5876
# weighted avg       0.73      0.78      0.75      5876
# C:\Users\Akshay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Akshay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Akshay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Let compare their accuracies
from sklearn.metrics import accuracy_score
lr_acc=accuracy_score(Y_test,lr_pred)
dt_acc=accuracy_score(Y_test,dt_pred)
rf_acc=accuracy_score(Y_test,rf_pred)
svm_acc=accuracy_score(Y_test,svm_pred)
print("Accuracy of logistic regression",lr_acc)
print("Accuracy of decision tree",dt_acc)
print("Accuracy of Random Forest",rf_acc)
print("Accuracy of Support Vector",svm_acc)
# Out:
# Accuracy of logistic regression 0.8170524166099388
# Accuracy of decision tree 0.9930224642614023
# Accuracy of Random Forest 0.9947243022464262
# Accuracy of Support Vector 0.7785908781484002

# %%
models=["logisticregression","decisiontree","random forest","SVM"]
accuracies=[lr_acc,dt_acc,rf_acc,svm_acc]
plt.bar(models,accuracies, color=['red','green','blue'])
plt.xlabel("ML Models")
plt.ylabel("Accuracy")
plt.show()

# %%
# Out of all the Algorithms, Random forest  works better with a nice accuracy followed by Decision tree
#and support vector

# %%
#LET'S PREDICT( random forest as it gives 99% accuracy)

# %%
X
# Out:
# array([[0.00000e+00, 5.20710e+02, 1.62800e+01, ..., 7.21300e+01,
#         8.36000e+00, 2.02000e+03],
#        [0.00000e+00, 1.68228e+03, 5.48400e+01, ..., 1.54530e+02,
#         2.73600e+01, 2.02000e+03],
#        [0.00000e+00, 1.81580e+03, 4.93500e+01, ..., 1.72630e+02,
#         2.81200e+01, 2.02000e+03],
#        ...,
#        [2.50000e+01, 3.90530e+02, 4.28000e+00, ..., 4.80600e+01,
#         1.20000e+00, 2.02300e+03],
#        [2.50000e+01, 3.00410e+02, 1.36000e+00, ..., 4.88900e+01,
#         0.00000e+00, 2.02300e+03],
#        [2.50000e+01, 4.27250e+02, 6.00000e+00, ..., 6.14100e+01,
#         2.00000e-01, 2.02300e+03]])

# %%
# prediction using decision tree
pred2=dt.predict([[25, 427.25, 6.00, 88.69, 10.73, 52.36, 61.41, 0.20, 2023]])
pred2
# Out:
# array([0])

# %%
# prediction using svm tree
pred3=svm.predict([[25, 427.25, 6.00, 88.69, 10.73, 52.36, 61.41, 0.20, 2023]])
pred3
# Out:
# array([0])

# %%
pred4=lr.predict([[0, 427.25, 6.00, 88.69, 10.73, 52.36, 61.41, 0.20, 2024]])
pred4
# Out:
# array([0])

# %%
#LET'S PREDICT for 2024

# %%
# prediction using random forest
pred1=rf.predict([[4, 42.25, 65.00, 882.69, 120.73, 512.36, 61.41, 0.20, 2024]])
pred1
# Out:
# array([4])
